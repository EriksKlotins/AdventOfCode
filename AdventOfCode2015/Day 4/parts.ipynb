# %%
test_inputs = [
    ['abcdef', 609043, '000001dbbfa' ],
    ['pqrstuv', 1048970, '000006136ef' ]

]

# %%
from  hashlib import md5

res = hashlib.md5(b'abcdef609043')
print(res.hexdigest())
# Out:
# 000001dbbfa3a5c83a2d506429c7b00e

# %% [markdown]
# # Part 1

# %%
# %%time
key = 'iwrupvqb'
for i in range(0,10000000):
    s = bytes(f"{key}{i}", encoding='utf-8' )
    hash = md5(s).hexdigest()
    if hash[:5] == '00000':
        print(hash, i)
        break
    # print(hash)
# Out:
# 0000045c5e2b3911eb937d9d8c574f09 346386
# CPU times: user 166 ms, sys: 1.77 ms, total: 167 ms
# Wall time: 166 ms

# %% [markdown]
# # Part II

# %%
# %%time
key = 'iwrupvqb'
for i in range(0,10000000):
    s = bytes(f"{key}{i}", encoding='utf-8' )
    hash = md5(s).hexdigest()
    if hash[:6] == '000000':
        print(hash, i)
        break
    # print(hash)
# Out:
# 00000094434e1914548b3a1af245fb27 9958218
# CPU times: user 4.49 s, sys: 5.34 ms, total: 4.5 s
# Wall time: 4.5 s
