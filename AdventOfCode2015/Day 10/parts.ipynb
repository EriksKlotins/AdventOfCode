# %%
# Your puzzle input is 1321131112.

# %%
tests = [
    (1, 11),
    (11,21),
    (21, 1211),
    (1211, 111221),
    (111221, 312211)
]

real_input = 1321131112

# %%
def parser(number):
    # arr = []

    number = str(number)+'x'
    result = ''
    prev = number[0]
    count = 0
    # count + digit
    for d in number:
        if d == prev:
            count +=1 
        else:
            result += str(count)+ prev
            # length += len(str(count))+1
            count = 1
        prev =d

    
    # print(result)
    return int(result)


for inp, result in tests:
    print(inp, parser(inp) == result)
# Out:
# 1 True
# 11 True
# 21 True
# 1211 True
# 111221 True

# %%
real_input = 1321131112
for i in range(40):
    # print(real_input)
    real_input = parser(real_input)

print(len(str(real_input)))
# Out:
# 492982

# %%
real_input = 1321131112
for i in range(50):
    # print(real_input)
    real_input = parser(real_input)

print(len(str(real_input)))
# Out:
# 6989950

# %%
10
