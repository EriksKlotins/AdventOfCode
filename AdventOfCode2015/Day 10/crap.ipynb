# %%
tests = [
    (1, 11),
    (11,21),
    (21, 1211),
    (1211, 111221),
    (111221, 312211)
]

real_input = 1321131112

# %%
def parser(number):
    # arr = []

    number = str(number)+'x'
    result = ''
    prev = number[0]
    count = 0
    # count + digit
    for d in number:
        if d == prev:
            count +=1 
        else:
            result += str(count)+ prev
            # length += len(str(count))+1
            count = 1
        prev =d

    
    # print(result)
    return int(result)


for inp, result in tests:
    print(inp, parser(inp) == result)
# Out:
# 1 True
# 11 True
# 21 True
# 1211 True
# 111221 True

# %%
d

# %%
# real_input = 1321131112
real_input = 1
for i in range(15):
    # print(real_input)
    real_input = parser(real_input)

    s = str(real_input)
    l = len(s) // 2

    print(s[0:l], s[l:] )
    # print(len(str(real_input)), real_input)
# Out:
# 1 1
# 2 1
# 12 11
# 111 221
# 312 211
# 1311 2221
# 11132 13211
# 3113121 1131221
# 1321131112 3113112211
# 1113122113311 2132113212221
# 31131122212321121 11312211312113211
# 13211321321112131221123 11311222113111221131221
# 1113122113121113123112111311222 1121321132132211331222113112211
# 311311222113111231131112132112311321322 112111312211312111322212311322113212221
# 132113213221133112132113311211131221121321131211132 221123113112221131112311332111213211322211312113211

# %%
real_input
# Out:
# 1113122113121113222123211211131211121311121321123113213221121113122113121122132112311321322112311311222113111231133221121113122113121113221112131221123113111231121123222112
