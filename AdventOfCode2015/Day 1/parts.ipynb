# %%
file_path = 'input.txt'
inp = ''
with open(file_path) as file:
    inp =  [line.rstrip() for line in file]

# %%
print(inp)
# Out:
# ['()(((()))(()()()((((()(((())(()(()((((((()(()(((())))((()(((()))((())(()((()()()()(((())(((((((())))()()(()(()(())(((((()()()((())(((((()()))))()(())(((())(())((((((())())))(()())))()))))()())()())((()()((()()()()(()((((((((()()())((()()(((((()(((())((())(()))()((((()((((((((())()((()())(())((()))())((((()())(((((((((((()()(((((()(()))())(((()(()))())((()(()())())())(()(((())(())())()()(()(()((()))((()))))((((()(((()))))((((()(()(()())())()(((()((((())((((()(((()()(())()()()())((()((((((()((()()))()((()))()(()()((())))(((()(((()))((()((()(()))(((()()(()(()()()))))()()(((()(((())())))))((()(((())()(()(())((()())))((((())))(()(()(()())()((()())))(((()((()(())()()((()((())(()()((())(())()))()))((()(())()))())(((((((()(()()(()(())())))))))(()((((((())((((())((())())(()()))))()(())(()())()())((())(()))))(()))(()((()))()(()((((((()()()()((((((((()(()(())((()()(()()))(())()())()((())))()))()())(((()))(())()(())()))()((()((()(()()())(())()()()((())())))((()()(()()((()(())()()())(((()(()())
# ...

# %%
2+4
# Out:
# 6

# %%
total = 0
for i, c in enumerate(list(inp[0])):
    total += 1 if c== '(' else -1
    if total < 0:
        print('Basement', i+1)
print(total)
# Out:
# Basement 1771
# Basement 1772
# Basement 1773
# Basement 1775
# Basement 1787
# Basement 1788
# Basement 1789
# Basement 1790
# Basement 1791
# Basement 1792
# Basement 1793
# Basement 1794
# Basement 1795
# Basement 1796
# Basement 1797
# Basement 1798
# Basement 1799
# Basement 1800
# Basement 1801
# Basement 1802
# Basement 1803
# Basement 1804
# Basement 1805
# Basement 1806
# Basement 1807
# Basement 1808
# Basement 1809
# Basement 1810
# Basement 1811
# Basement 1812
# Basement 1813
# Basement 1814
# Basement 1815
# Basement 1816
# Basement 1817
# Basement 1818
# Basement 1819
# Basement 1820
# Basement 1821
# Basement 1822
# Basement 1823
# Basement 1824
# Basement 1825
# Basement 1826
# Basement 1827
# Basement 1828
# Basement 1829
# Basement 1830
# Basement 1831
# Basement 1832
# Basement 1833
# Basement 1834
# Basement 1835
# Basement 1836
# Basement 1837
# Basement 1838
# Basement 1839
# Basement 1840
# Basement 1841
# Basement 1842
# Basement 1843
# Basement 1844
# ...

# %%
list(inp[0])
# Out:
# ['(',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  ')',
#  ')',
#  '(',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  ')',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  ')',
#  ')',
#  ')',
#  '(',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  ')',
#  ')',
#  '(',
#  '(',
#  '(',
#  ')',
#  ')',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  ')',
#  ')',
#  ')',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  ')',
#  '(',
#  '(',
#  ')',
#  ')',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  '(',
#  ')',
#  '(',
#  ')',
#  '(',
#  ')',
# ...
